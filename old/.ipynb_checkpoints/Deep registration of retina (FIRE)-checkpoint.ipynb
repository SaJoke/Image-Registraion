# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import glob,cv2,time,random
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras import layers

# %%
# Dense image warp from Tensorflow addons
# There is an error using tfa.image.dense_image_warp
# define same tfa.image.dense_image_warp

from tensorflow_addons.utils import types
from typing import Optional

def _get_dim(x, idx):
    if x.shape.ndims is None:
        return tf.shape(x)[idx]
    return x.shape[idx] or tf.shape(x)[idx]

def dense_image_warp(image: types.TensorLike, displacement: types.TensorLike, name: Optional[str] = None) -> tf.Tensor:
    with tf.name_scope(name or "dense_image_warp"):
        image = tf.convert_to_tensor(image)
        displacement = tf.convert_to_tensor(displacement)
        batch_size, height, width, channels = (
            _get_dim(image, 0),
            _get_dim(image, 1),
            _get_dim(image, 2),
            _get_dim(image, 3),
        )

        # The flow is defined on the image grid. Turn the flow into a list of query
        # points in the grid space.
        grid_x, grid_y = tf.meshgrid(tf.range(width), tf.range(height))
        stacked_grid = tf.cast(tf.stack([grid_y, grid_x], axis=2), displacement.dtype)
        batched_grid = tf.expand_dims(stacked_grid, axis=0)
        query_points_on_grid = batched_grid + displacement
        query_points_flattened = tf.reshape(query_points_on_grid, [batch_size, height * width, 2])
        # Compute values at the query points, then reshape the result back to the
        # image grid.
        interpolated = tfa.image.interpolate_bilinear(image, query_points_flattened)
        interpolated = tf.reshape(interpolated, [batch_size, height, width, channels])
        return interpolated

# %%
_dir = r'FIRE'
img_dir = _dir+'/Images/'
gt_dir = _dir+'/Ground Truth/control_points_'

# %%
def gt_read(file_name):
    gt_file = open(file_name)
    gt_list = []
    for keypoint in gt_file.readlines():
        gt_list.append(keypoint.split())
    return np.array(gt_list).astype(float).astype(int)

# %%
dataset = []
img_shape = (256,256)
for category in ['A','P','S']:
    print(category)
    img_names = glob.glob(img_dir+category+'*.*')
    gt_names = np.array(glob.glob(gt_dir+category+'*.*'))
    n = len(img_names)//2
    pairs = np.array(img_names).reshape(n,2)
    for i in range(n):
        img1 = plt.imread(pairs[i,0])
        original_shape = img1.shape[1]
        img1 = cv2.resize(img1,img_shape)
        img2 = cv2.resize(plt.imread(pairs[i,1]),img_shape)
        img_pairs = np.array([img1,img2])
        gt = gt_read(gt_names[i])*img_shape[1]/original_shape
        dataset = np.append(dataset,[category,img_pairs,gt])
dataset = dataset.reshape(dataset.shape[0]//3,3)
# Out:
# A
# C:\Users\Admin\anaconda3\envs\tf2\lib\site-packages\numpy\core\fromnumeric.py:1822: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asanyarray(a).ravel(order=order)
# P
# S

# %%
_id = 23
img1 = dataset[_id,1][0].copy()
img2 = dataset[_id,1][1].copy()
for kp in dataset[_id,2]:
    kp = np.int32(kp)
    cv2.circle(img1,(kp[0],kp[1]),img1.shape[0]//120,(255, 255, 255),-1)
    cv2.circle(img2,(kp[2],kp[3]),img2.shape[0]//120,(255, 255, 255),-1)
plt.figure(figsize=(15,15))
plt.subplot(121)
plt.imshow(img1)
plt.subplot(122)
plt.imshow(img2)
plt.show()

# %%
N = dataset.shape[0]
train_ratio = 0.9
train_size = int(train_ratio*N)
train_ind = random.sample(range(0,N),train_size)

# %%
train_set = []
test_set = []
gt_train = []
gt_test = []
for ind in range(N):
    fixed_img = dataset[ind,1][0]
    moved_img = dataset[ind,1][1]
    if ind in train_ind:
        train_set.append(np.concatenate((fixed_img,moved_img),axis=-1))
        gt_train.append(dataset[ind,2])
    else:
        test_set.append(np.concatenate((fixed_img,moved_img),axis=-1))
        gt_test.append(dataset[ind,2])
train_set = tf.convert_to_tensor(train_set,float)/255
test_set = tf.convert_to_tensor(test_set,float)/255
gt_train = tf.convert_to_tensor(gt_train,float)
gt_test = tf.convert_to_tensor(gt_test,float)

# %%
def img_grad(imgs):
    img_x,img_y = tf.image.image_gradients(imgs)
    img_x,img_y = (img_x+tf.roll(img_x,1,1))/2, (img_y+tf.roll(img_y,1,2))/2
    return img_x,img_y

def gauss_n_down(imgs,filter_shape,down_shape):
    return tf.image.resize(tfa.image.gaussian_filter2d(imgs,filter_shape=filter_shape),down_shape)

# %%
def D_MSE(img1,img2):
    return tf.reduce_mean(tf.square(img1-img2))

def D_CC(img1,img2,n=9):
    gs_img1 = tfa.image.gaussian_filter2d(img1,filter_shape=(n,n))
    gs_img2 = tfa.image.gaussian_filter2d(img2,filter_shape=(n,n))
    dif_img1 = img1-gs_img1
    dif_img2 = img2-gs_img2
    cc = tf.reduce_sum(dif_img1*dif_img2,axis=[1,2,3])**2
    cc = cc/(tf.reduce_sum(dif_img1**2,axis=[1,2,3])*tf.reduce_sum(dif_img2**2,axis=[1,2,3]))
    return tf.reduce_mean(cc)

def D_NGF(img1,img2,e=1e-3):
    img1_x,img1_y = img_grad(img1)
    img2_x,img2_y = img_grad(img2)
    inner = lambda a,b: a*b+e**2
    norm_s = lambda a,b: inner(a,a)+inner(b,b)
    ngf = 1 - ((inner(img1_x,img2_x)+inner(img1_y,img2_y))**2)/(norm_s(img1_x,img1_y)*norm_s(img2_x,img2_y))
    return tf.reduce_mean(tf.reduce_sum(ngf,axis=[1,2,3]))
    
def R_difsn(u):
    u_x,u_y = img_grad(u)
    difsn = tf.cast(tf.math.reduce_sum(u_x**2+u_y**2,axis=[1,2,3]),tf.float64)
    tf.reduce_mean(difsn)

def R_curv(u):
    u_x,u_y = tf.image.image_gradients(u) #forward different
    u_xx = u_x-tf.roll(u_x,1,1)
    u_yy = u_y-tf.roll(u_y,1,2)
    return tf.reduce_mean(tf.reduce_sum(u_xx**2+u_yy**2,axis=[1,2,3]))

def R_fold(u,t):
    u_x,u_y = tf.image.image_gradients(u)
    det_u = u_x[:,:,:,0]*u_y[:,:,:,1]-u_x[:,:,:,1]*u_y[:,:,:,0]
    mt_t = det_u[det_u>=t]
    lt_t = det_u[det_u<t]
    return (tf.reduce_sum((mt_t-1)**2/mt_t)+tf.reduce_sum((1-1/t**2)*lt_t+(2*(1-t)/t)))/tf.cast(tf.shape(u)[0],float)

# %%
# inputs = layers.Input(shape=train_set[0].shape)
# Conv2D = lambda l: layers.Conv2D(l,3,activation='relu',padding='same')
# Maxpool2D = layers.MaxPool2D()
# UpSampling2D = layers.UpSampling2D()
# Concatenate = layers.Concatenate()

# x = Conv2D(16)(inputs)
# skip = []
# for _ in range(4):
#     skip.append(x)
#     x = Maxpool2D(x)
#     x = Conv2D(32)(x)
# for _ in range(4):
#     x = UpSampling2D(x)
#     x = Concatenate([x,skip.pop()])
#     x = Conv2D(32)(x)
# x = Conv2D(16)(x)
# x = Conv2D(16)(x)
# x = tf.keras.layers.Conv2D(2,3,padding='same')(x)
# model = tf.keras.Model(inputs=inputs, outputs=x,name='model')
# model.summary()
# weight_save = model.get_weights()

# %%
Conv2D = lambda l: layers.Conv2D(l,3,activation='relu',padding='same')
AveragePooling2D = layers.AveragePooling2D()
UpSampling2D = layers.UpSampling2D()
Concatenate = layers.Concatenate()

multi_layers = 3
model_list = []
if len(model_list)==0:
    for ly in range(multi_layers):
        multiplier = 2**(multi_layers-ly-1)
        rs = img_shape[0]//multiplier
        inputs = layers.Input(shape=(rs,rs,6))
        x = Conv2D(16)(inputs)
        x = Conv2D(16)(x)
        skip = []
        for i in range(3):
            skip.append(x)
            x =AveragePooling2D(x)
            l = 32*2**i
            x = Conv2D(l)(x)
            x = Conv2D(l)(x)
        for j in range(3):
            x = UpSampling2D(x)
            x = Concatenate([x,skip.pop()])
            l = 16*2**(2-j)
            x = Conv2D(l)(x)
            x = Conv2D(l)(x)
        x = tf.keras.layers.Conv2D(2,1,padding='same')(x)
        model = tf.keras.Model(inputs=inputs, outputs=x,name='model{}'.format(ly))
        model.summary(line_length=120)
        model_list.append(model)
    weight_save = model_list[0].get_weights()
# Out:
# Model: "model0"
# ________________________________________________________________________________________________________________________
# Layer (type)                           Output Shape               Param #       Connected to
# ========================================================================================================================
# input_1 (InputLayer)                   [(None, 64, 64, 6)]        0
# ________________________________________________________________________________________________________________________
# conv2d (Conv2D)                        (None, 64, 64, 16)         880           input_1[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_1 (Conv2D)                      (None, 64, 64, 16)         2320          conv2d[0][0]
# ________________________________________________________________________________________________________________________
# average_pooling2d (AveragePooling2D)   multiple                   0             conv2d_1[0][0]
#                                                                                 conv2d_3[0][0]
#                                                                                 conv2d_5[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_2 (Conv2D)                      (None, 32, 32, 32)         4640          average_pooling2d[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_3 (Conv2D)                      (None, 32, 32, 32)         9248          conv2d_2[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_4 (Conv2D)                      (None, 16, 16, 64)         18496         average_pooling2d[1][0]
# ________________________________________________________________________________________________________________________
# conv2d_5 (Conv2D)                      (None, 16, 16, 64)         36928         conv2d_4[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_6 (Conv2D)                      (None, 8, 8, 128)          73856         average_pooling2d[2][0]
# ________________________________________________________________________________________________________________________
# conv2d_7 (Conv2D)                      (None, 8, 8, 128)          147584        conv2d_6[0][0]
# ________________________________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)           multiple                   0             conv2d_7[0][0]
#                                                                                 conv2d_9[0][0]
#                                                                                 conv2d_11[0][0]
# ________________________________________________________________________________________________________________________
# concatenate (Concatenate)              multiple                   0             up_sampling2d[0][0]
#                                                                                 conv2d_5[0][0]
#                                                                                 up_sampling2d[1][0]
#                                                                                 conv2d_3[0][0]
#                                                                                 up_sampling2d[2][0]
#                                                                                 conv2d_1[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_8 (Conv2D)                      (None, 16, 16, 64)         110656        concatenate[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_9 (Conv2D)                      (None, 16, 16, 64)         36928         conv2d_8[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_10 (Conv2D)                     (None, 32, 32, 32)         27680         concatenate[1][0]
# ________________________________________________________________________________________________________________________
# conv2d_11 (Conv2D)                     (None, 32, 32, 32)         9248          conv2d_10[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_12 (Conv2D)                     (None, 64, 64, 16)         6928          concatenate[2][0]
# ________________________________________________________________________________________________________________________
# conv2d_13 (Conv2D)                     (None, 64, 64, 16)         2320          conv2d_12[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_14 (Conv2D)                     (None, 64, 64, 2)          34            conv2d_13[0][0]
# ========================================================================================================================
# Total params: 487,746
# Trainable params: 487,746
# Non-trainable params: 0
# ________________________________________________________________________________________________________________________
# Model: "model1"
# ________________________________________________________________________________________________________________________
# Layer (type)                           Output Shape               Param #       Connected to
# ========================================================================================================================
# input_2 (InputLayer)                   [(None, 128, 128, 6)]      0
# ________________________________________________________________________________________________________________________
# conv2d_15 (Conv2D)                     (None, 128, 128, 16)       880           input_2[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_16 (Conv2D)                     (None, 128, 128, 16)       2320          conv2d_15[0][0]
# ________________________________________________________________________________________________________________________
# average_pooling2d (AveragePooling2D)   multiple                   0             conv2d_16[0][0]
#                                                                                 conv2d_18[0][0]
#                                                                                 conv2d_20[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_17 (Conv2D)                     (None, 64, 64, 32)         4640          average_pooling2d[3][0]
# ________________________________________________________________________________________________________________________
# conv2d_18 (Conv2D)                     (None, 64, 64, 32)         9248          conv2d_17[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_19 (Conv2D)                     (None, 32, 32, 64)         18496         average_pooling2d[4][0]
# ________________________________________________________________________________________________________________________
# conv2d_20 (Conv2D)                     (None, 32, 32, 64)         36928         conv2d_19[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_21 (Conv2D)                     (None, 16, 16, 128)        73856         average_pooling2d[5][0]
# ________________________________________________________________________________________________________________________
# conv2d_22 (Conv2D)                     (None, 16, 16, 128)        147584        conv2d_21[0][0]
# ________________________________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)           multiple                   0             conv2d_22[0][0]
#                                                                                 conv2d_24[0][0]
#                                                                                 conv2d_26[0][0]
# ________________________________________________________________________________________________________________________
# concatenate (Concatenate)              multiple                   0             up_sampling2d[3][0]
#                                                                                 conv2d_20[0][0]
#                                                                                 up_sampling2d[4][0]
#                                                                                 conv2d_18[0][0]
#                                                                                 up_sampling2d[5][0]
#                                                                                 conv2d_16[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_23 (Conv2D)                     (None, 32, 32, 64)         110656        concatenate[3][0]
# ________________________________________________________________________________________________________________________
# conv2d_24 (Conv2D)                     (None, 32, 32, 64)         36928         conv2d_23[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_25 (Conv2D)                     (None, 64, 64, 32)         27680         concatenate[4][0]
# ________________________________________________________________________________________________________________________
# conv2d_26 (Conv2D)                     (None, 64, 64, 32)         9248          conv2d_25[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_27 (Conv2D)                     (None, 128, 128, 16)       6928          concatenate[5][0]
# ________________________________________________________________________________________________________________________
# conv2d_28 (Conv2D)                     (None, 128, 128, 16)       2320          conv2d_27[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_29 (Conv2D)                     (None, 128, 128, 2)        34            conv2d_28[0][0]
# ========================================================================================================================
# Total params: 487,746
# Trainable params: 487,746
# Non-trainable params: 0
# ________________________________________________________________________________________________________________________
# Model: "model2"
# ________________________________________________________________________________________________________________________
# Layer (type)                           Output Shape               Param #       Connected to
# ========================================================================================================================
# input_3 (InputLayer)                   [(None, 256, 256, 6)]      0
# ________________________________________________________________________________________________________________________
# conv2d_30 (Conv2D)                     (None, 256, 256, 16)       880           input_3[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_31 (Conv2D)                     (None, 256, 256, 16)       2320          conv2d_30[0][0]
# ________________________________________________________________________________________________________________________
# average_pooling2d (AveragePooling2D)   multiple                   0             conv2d_31[0][0]
#                                                                                 conv2d_33[0][0]
#                                                                                 conv2d_35[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_32 (Conv2D)                     (None, 128, 128, 32)       4640          average_pooling2d[6][0]
# ________________________________________________________________________________________________________________________
# conv2d_33 (Conv2D)                     (None, 128, 128, 32)       9248          conv2d_32[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_34 (Conv2D)                     (None, 64, 64, 64)         18496         average_pooling2d[7][0]
# ________________________________________________________________________________________________________________________
# conv2d_35 (Conv2D)                     (None, 64, 64, 64)         36928         conv2d_34[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_36 (Conv2D)                     (None, 32, 32, 128)        73856         average_pooling2d[8][0]
# ________________________________________________________________________________________________________________________
# conv2d_37 (Conv2D)                     (None, 32, 32, 128)        147584        conv2d_36[0][0]
# ________________________________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)           multiple                   0             conv2d_37[0][0]
#                                                                                 conv2d_39[0][0]
#                                                                                 conv2d_41[0][0]
# ________________________________________________________________________________________________________________________
# concatenate (Concatenate)              multiple                   0             up_sampling2d[6][0]
#                                                                                 conv2d_35[0][0]
#                                                                                 up_sampling2d[7][0]
#                                                                                 conv2d_33[0][0]
#                                                                                 up_sampling2d[8][0]
#                                                                                 conv2d_31[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_38 (Conv2D)                     (None, 64, 64, 64)         110656        concatenate[6][0]
# ________________________________________________________________________________________________________________________
# conv2d_39 (Conv2D)                     (None, 64, 64, 64)         36928         conv2d_38[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_40 (Conv2D)                     (None, 128, 128, 32)       27680         concatenate[7][0]
# ________________________________________________________________________________________________________________________
# conv2d_41 (Conv2D)                     (None, 128, 128, 32)       9248          conv2d_40[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_42 (Conv2D)                     (None, 256, 256, 16)       6928          concatenate[8][0]
# ________________________________________________________________________________________________________________________
# conv2d_43 (Conv2D)                     (None, 256, 256, 16)       2320          conv2d_42[0][0]
# ________________________________________________________________________________________________________________________
# conv2d_44 (Conv2D)                     (None, 256, 256, 2)        34            conv2d_43[0][0]
# ========================================================================================================================
# Total params: 487,746
# Trainable params: 487,746
# Non-trainable params: 0
# ________________________________________________________________________________________________________________________

# %%
def loss_fn(model,imgs,r_con=[10,0.01],t=None):
    u = model(imgs)
    ref_img = imgs[:,:,:,:3]
    warped_img = dense_image_warp(imgs[:,:,:,3:],u)
    loss = D_NGF(ref_img,warped_img)+r_con[0]*R_curv(u)+r_con[1]*R_fold(u,t)
    return loss

def grad_fn(model,imgs,t=None):
    with tf.GradientTape() as tape:
        loss_value = loss_fn(model,imgs,t=t)
    return loss_value, tape.gradient(loss_value, model.trainable_variables)

def MDE_fn(u,gts):
    m = []
    for i in range(u.shape[0]):
        for j in range(gts.shape[1]):
            gt = gts[i,j]
            v = u[i][int(gt[0]),int(gt[1]),:]
            pt = tf.sqrt(tf.reduce_sum((gt[:2]+v-gt[2:])**2))
            m.append(pt)
    return tf.reduce_mean(m)

def count_fold_fn(u):
    u_x,u_y = tf.image.image_gradients(u)
    det_u = u_x[:,:,:,0]*u_y[:,:,:,1]-u_x[:,:,:,1]*u_y[:,:,:,0]
    return tf.math.count_nonzero(det_u<=0)

# %%
'''model.set_weights(weight_save)
epochs = 20
batch_size = train_size//10
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

loss_log = []
metric_log = []
for epoch in range(epochs):
    loss_epoch = []
    metric_epoch = []
    for i in range(0,train_size,batch_size):
        train_batch = train_set[i:i+batch_size]
        gt_batch = gt_train[i:i+batch_size]
        loss_batch, metric_batch, grads = grad_fn(model,train_batch,gt_batch)
        optimizer.apply_gradients(zip(grads, model.trainable_variables))
        loss_epoch.append(loss_batch.numpy())
        metric_epoch.append(metric_batch)
    loss_test, metric_test = loss_fn(model,test_set,gt_test)
    loss_log = np.append(loss_log,[np.mean(loss_epoch),loss_test])
    metric_log = np.append(metric_log,[np.mean(metric_epoch),metric_test])
    dgt = 4 #display 'dgt' digits
    print('epoch {}, loss_train {}, loss_test {}, metric_train {}, metric_test {}'
          .format(epoch,np.round(loss_log[-2],dgt),np.round(loss_log[-1],dgt),np.round(metric_log[-2],dgt),np.round(metric_log[-1],dgt)))
loss_log = loss_log.reshape(20,2)
metric_log = metric_log.reshape(20,2)'''
# Out:
# "model.set_weights(weight_save)\nepochs = 20\nbatch_size = train_size//10\noptimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)\n\nloss_log = []\nmetric_log = []\nfor epoch in range(epochs):\n    loss_epoch = []\n    metric_epoch = []\n    for i in range(0,train_size,batch_size):\n        train_batch = train_set[i:i+batch_size]\n        gt_batch = gt_train[i:i+batch_size]\n        loss_batch, metric_batch, grads = grad_fn(model,train_batch,gt_batch)\n        optimizer.apply_gradients(zip(grads, model.trainable_variables))\n        loss_epoch.append(loss_batch.numpy())\n        metric_epoch.append(metric_batch)\n    loss_test, metric_test = loss_fn(model,test_set,gt_test)\n    loss_log = np.append(loss_log,[np.mean(loss_epoch),loss_test])\n    metric_log = np.append(metric_log,[np.mean(metric_epoch),metric_test])\n    dgt = 4 #display 'dgt' digits\n    print('epoch {}, loss_train {}, loss_test {}, metric_train {}, metric_test {}'\n          .format(epoch,np.round(loss_log[-2],dgt),np.round(loss_log[-1],dgt),np.round(metric_log[-2],dgt),np.round(metric_log[-1],dgt)))\nloss_log = loss_log.reshape(20,2)\nmetric_log = metric_log.reshape(20,2)"

# %%
model_list[0].set_weights(weight_save)
epochs = 25
batch_size = train_size//10
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

loss_log = []
metric_log = []
start_time = time.time()
loss_ts_log = []
test_set_full = test_set
for ly in range(multi_layers):
    epochs = 250 if ly==0 else 25
    for epoch in range(epochs):
        loss_epoch = []
        metric_epoch = []
        fs0 = 2**(multi_layers)-1
        multiplier0 = 2**(multi_layers-1)
        rs0 = img_shape[0]//multiplier0
        for i in range(0,train_size,batch_size):
            fs = fs0
            multiplier = multiplier0
            rs = rs0
            #initial input
            train_batch_full = train_set[i:i+batch_size]
            train_batch = gauss_n_down(train_batch_full,(fs,fs),(rs,rs))
            for j in range(ly):
                u = model_list[j](train_batch)
                u = tf.image.resize(u,img_shape)*multiplier
                warped_img = dense_image_warp(train_batch_full[:,:,:,3:],u)
                train_batch_full = tf.concat([train_batch_full[:,:,:,:3],warped_img],axis=-1)
                multiplier = multiplier//2
                fs = (fs-1)//2
                rs = 2*rs
                train_batch = gauss_n_down(train_batch_full,(fs,fs),(rs,rs))
            
            #train model
            loss_batch, grads = grad_fn(model_list[ly],train_batch,t=0.2/2**ly)
            optimizer.apply_gradients(zip(grads,model_list[ly].trainable_variables))
            
            loss_epoch.append(loss_batch.numpy())
        dgt = 4
        loss_log = np.append(loss_log,np.mean(loss_epoch))
        if ly<(multi_layers-1):
            print('layer {}, epoch {}, loss_train {}'.format(ly,epoch,np.round(loss_log[-1],dgt)))
        else:
            test_set_small = gauss_n_down(test_set_full,(fs0,fs0),(rs0,rs0))
            for j in range(ly):
                u = model_list[j](test_set_small)
                u = tf.image.resize(u,img_shape)*multiplier0
                warped_img = dense_image_warp(test_set_full[:,:,:,3:],u)
                test_set_full = tf.concat([test_set_full[:,:,:,:3],warped_img],axis=-1)
                multiplier0 = multiplier0//2
                fs0 = (fs0-1)//2
                rs0 = 2*rs0
                test_set_small = gauss_n_down(test_set_full,(fs0,fs0),(rs0,rs0))
            loss_test = loss_fn(model_list[ly],test_set_small,t=0.2/2**ly).numpy()
            loss_ts_log.append(loss_test)
            print('layer {}, epoch {}, loss_train {}, loss_train {}'
                  .format(ly,epoch,np.round(loss_log[-1],dgt),np.round(loss_test,dgt)))
            
print('time used = {} second'.format(time.time()-start_time))
# Out:
# layer 0, epoch 0, loss_train 3710.0618
# layer 0, epoch 1, loss_train 3691.4062
# layer 0, epoch 2, loss_train 3686.4539
# layer 0, epoch 3, loss_train 3681.741
# layer 0, epoch 4, loss_train 3679.1675
# layer 0, epoch 5, loss_train 3678.3784
# layer 0, epoch 6, loss_train 3676.8386
# layer 0, epoch 7, loss_train 3676.2417
# layer 0, epoch 8, loss_train 3673.7883
# layer 0, epoch 9, loss_train 3675.5586
# layer 0, epoch 10, loss_train 3673.8821
# layer 0, epoch 11, loss_train 3672.4207
# layer 0, epoch 12, loss_train 3672.2461
# layer 0, epoch 13, loss_train 3663.2661
# layer 0, epoch 14, loss_train 3660.7336
# layer 0, epoch 15, loss_train 3654.4207
# layer 0, epoch 16, loss_train 3651.4832
# layer 0, epoch 17, loss_train 3647.6379
# layer 0, epoch 18, loss_train 3645.6238
# layer 0, epoch 19, loss_train 3644.5776
# layer 0, epoch 20, loss_train 3642.6472
# layer 0, epoch 21, loss_train 3641.7754
# layer 0, epoch 22, loss_train 3639.2305
# layer 0, epoch 23, loss_train 3640.1218
# layer 0, epoch 24, loss_train 3630.1641
# layer 0, epoch 25, loss_train 3644.9563
# layer 0, epoch 26, loss_train 3633.7136
# layer 0, epoch 27, loss_train 3633.9387
# layer 0, epoch 28, loss_train 3626.1453
# layer 0, epoch 29, loss_train 3628.0454
# layer 0, epoch 30, loss_train 3622.5085
# layer 0, epoch 31, loss_train 3624.5327
# layer 0, epoch 32, loss_train 3620.1738
# layer 0, epoch 33, loss_train 3622.2976
# layer 0, epoch 34, loss_train 3619.0176
# layer 0, epoch 35, loss_train 3620.1167
# layer 0, epoch 36, loss_train 3616.6692
# layer 0, epoch 37, loss_train 3616.418
# layer 0, epoch 38, loss_train 3615.3765
# layer 0, epoch 39, loss_train 3618.6099
# layer 0, epoch 40, loss_train 3614.147
# layer 0, epoch 41, loss_train 3612.1226
# layer 0, epoch 42, loss_train 3609.8171
# layer 0, epoch 43, loss_train 3606.2349
# layer 0, epoch 44, loss_train 3613.334
# layer 0, epoch 45, loss_train 3610.4585
# layer 0, epoch 46, loss_train 3620.8794
# layer 0, epoch 47, loss_train 3615.5005
# layer 0, epoch 48, loss_train 3613.6516
# layer 0, epoch 49, loss_train 3613.6763
# layer 0, epoch 50, loss_train 3611.7749
# layer 0, epoch 51, loss_train 3609.4602
# layer 0, epoch 52, loss_train 3604.3015
# layer 0, epoch 53, loss_train 3605.4731
# layer 0, epoch 54, loss_train 3606.0493
# layer 0, epoch 55, loss_train 3603.6296
# layer 0, epoch 56, loss_train 3601.98
# layer 0, epoch 57, loss_train 3603.8164
# layer 0, epoch 58, loss_train 3602.2043
# layer 0, epoch 59, loss_train 3599.3804
# layer 0, epoch 60, loss_train 3593.0977
# layer 0, epoch 61, loss_train 3597.644
# layer 0, epoch 62, loss_train 3600.2007
# layer 0, epoch 63, loss_train 3606.3315
# layer 0, epoch 64, loss_train 3602.7742
# layer 0, epoch 65, loss_train 3604.9434
# layer 0, epoch 66, loss_train 3597.6379
# layer 0, epoch 67, loss_train 3590.5391
# layer 0, epoch 68, loss_train 3585.2788
# layer 0, epoch 69, loss_train 3584.5347
# layer 0, epoch 70, loss_train 3588.05
# layer 0, epoch 71, loss_train 3593.6785
# layer 0, epoch 72, loss_train 3609.3
# layer 0, epoch 73, loss_train 3611.6785
# layer 0, epoch 74, loss_train 3603.5991
# layer 0, epoch 75, loss_train 3597.4583
# layer 0, epoch 76, loss_train 3589.9915
# layer 0, epoch 77, loss_train 3613.0298
# layer 0, epoch 78, loss_train 3608.9556
# layer 0, epoch 79, loss_train 3602.0571
# layer 0, epoch 80, loss_train 3591.2527
# layer 0, epoch 81, loss_train 3594.4148
# layer 0, epoch 82, loss_train 3585.3105
# layer 0, epoch 83, loss_train 3579.3
# layer 0, epoch 84, loss_train 3577.3403
# layer 0, epoch 85, loss_train 3586.627
# layer 0, epoch 86, loss_train 3583.3418
# layer 0, epoch 87, loss_train 3575.3308
# layer 0, epoch 88, loss_train 3571.1633
# layer 0, epoch 89, loss_train 3581.748
# layer 0, epoch 90, loss_train 3582.7043
# layer 0, epoch 91, loss_train 3578.5222
# layer 0, epoch 92, loss_train 3569.7859
# layer 0, epoch 93, loss_train 3571.0906
# layer 0, epoch 94, loss_train 3567.1965
# layer 0, epoch 95, loss_train 3582.9622
# layer 0, epoch 96, loss_train 3602.4993
# layer 0, epoch 97, loss_train 3599.5059
# layer 0, epoch 98, loss_train 3600.0872
# layer 0, epoch 99, loss_train 3584.3367
# layer 0, epoch 100, loss_train 3573.8149
# layer 0, epoch 101, loss_train 3562.1519
# layer 0, epoch 102, loss_train 3556.8469
# layer 0, epoch 103, loss_train 3564.6909
# layer 0, epoch 104, loss_train 3578.6636
# layer 0, epoch 105, loss_train 3588.1523
# layer 0, epoch 106, loss_train 3585.45
# layer 0, epoch 107, loss_train 3577.5786
# layer 0, epoch 108, loss_train 3572.8215
# layer 0, epoch 109, loss_train 3570.5312
# layer 0, epoch 110, loss_train 3569.3589
# layer 0, epoch 111, loss_train 3573.0796
# layer 0, epoch 112, loss_train 3564.9141
# layer 0, epoch 113, loss_train 3559.8699
# layer 0, epoch 114, loss_train 3561.03
# layer 0, epoch 115, loss_train 3563.1108
# layer 0, epoch 116, loss_train 3564.6035
# layer 0, epoch 117, loss_train 3567.0547
# layer 0, epoch 118, loss_train 3568.0261
# layer 0, epoch 119, loss_train 3556.0762
# layer 0, epoch 120, loss_train 3552.0137
# layer 0, epoch 121, loss_train 3550.3711
# layer 0, epoch 122, loss_train 3549.4238
# layer 0, epoch 123, loss_train 3564.7222
# layer 0, epoch 124, loss_train 3555.2734
# layer 0, epoch 125, loss_train 3539.946
# layer 0, epoch 126, loss_train 3544.4614
# layer 0, epoch 127, loss_train 3556.0066
# layer 0, epoch 128, loss_train 3547.6655
# layer 0, epoch 129, loss_train 3535.563
# layer 0, epoch 130, loss_train 3543.019
# layer 0, epoch 131, loss_train 3544.2664
# layer 0, epoch 132, loss_train 3539.5874
# layer 0, epoch 133, loss_train 3554.4004
# layer 0, epoch 134, loss_train 3556.0925
# layer 0, epoch 135, loss_train 3559.8984
# layer 0, epoch 136, loss_train 3557.3359
# layer 0, epoch 137, loss_train 3539.2241
# layer 0, epoch 138, loss_train 3526.8848
# layer 0, epoch 139, loss_train 3522.5613
# layer 0, epoch 140, loss_train 3544.9648
# layer 0, epoch 141, loss_train 3546.9204
# layer 0, epoch 142, loss_train 3545.3589
# layer 0, epoch 143, loss_train 3544.1812
# layer 0, epoch 144, loss_train 3538.9468
# layer 0, epoch 145, loss_train 3543.4004
# layer 0, epoch 146, loss_train 3534.7083
# layer 0, epoch 147, loss_train 3522.9851
# layer 0, epoch 148, loss_train 3526.2734
# layer 0, epoch 149, loss_train 3524.4438
# layer 0, epoch 150, loss_train 3520.3159
# layer 0, epoch 151, loss_train 3541.0039
# layer 0, epoch 152, loss_train 3530.1562
# layer 0, epoch 153, loss_train 3508.6843
# layer 0, epoch 154, loss_train 3510.0688
# layer 0, epoch 155, loss_train 3509.5188
# layer 0, epoch 156, loss_train 3519.9622
# layer 0, epoch 157, loss_train 3505.1079
# layer 0, epoch 158, loss_train 3514.4253
# layer 0, epoch 159, loss_train 3494.5356
# layer 0, epoch 160, loss_train 3507.0396
# layer 0, epoch 161, loss_train 3487.6594
# layer 0, epoch 162, loss_train 3492.7944
# layer 0, epoch 163, loss_train 3520.8345
# layer 0, epoch 164, loss_train 3558.1147
# layer 0, epoch 165, loss_train 3539.0913
# layer 0, epoch 166, loss_train 3524.9634
# layer 0, epoch 167, loss_train 3517.5332
# layer 0, epoch 168, loss_train 3528.1831
# layer 0, epoch 169, loss_train 3529.9058
# layer 0, epoch 170, loss_train 3513.2078
# layer 0, epoch 171, loss_train 3516.2551
# layer 0, epoch 172, loss_train 3498.353
# layer 0, epoch 173, loss_train 3495.748
# layer 0, epoch 174, loss_train 3495.1047
# layer 0, epoch 175, loss_train 3484.5144
# layer 0, epoch 176, loss_train 3489.7996
# layer 0, epoch 177, loss_train 3484.2546
# layer 0, epoch 178, loss_train 3493.9116
# layer 0, epoch 179, loss_train 3504.1868
# layer 0, epoch 180, loss_train 3488.0359
# layer 0, epoch 181, loss_train 3484.3008
# layer 0, epoch 182, loss_train 3486.2593
# layer 0, epoch 183, loss_train 3503.7507
# layer 0, epoch 184, loss_train 3487.5149
# layer 0, epoch 185, loss_train 3483.845
# layer 0, epoch 186, loss_train 3482.8113
# layer 0, epoch 187, loss_train 3490.3203
# layer 0, epoch 188, loss_train 3473.4155
# layer 0, epoch 189, loss_train 3465.6809
# layer 0, epoch 190, loss_train 3472.8706
# layer 0, epoch 191, loss_train 3504.8958
# layer 0, epoch 192, loss_train 3489.4753
# layer 0, epoch 193, loss_train 3475.6301
# layer 0, epoch 194, loss_train 3494.7617
# layer 0, epoch 195, loss_train 3490.0391
# layer 0, epoch 196, loss_train 3536.8418
# layer 0, epoch 197, loss_train 3546.0156
# layer 0, epoch 198, loss_train 3531.25
# layer 0, epoch 199, loss_train 3521.4434
# layer 0, epoch 200, loss_train 3493.9956
# layer 0, epoch 201, loss_train 3469.8411
# layer 0, epoch 202, loss_train 3461.1343
# layer 0, epoch 203, loss_train 3455.8247
# layer 0, epoch 204, loss_train 3456.2759
# layer 0, epoch 205, loss_train 3465.7378
# layer 0, epoch 206, loss_train 3497.7017
# layer 0, epoch 207, loss_train 3478.0547
# layer 0, epoch 208, loss_train 3475.3093
# layer 0, epoch 209, loss_train 3456.2769
# layer 0, epoch 210, loss_train 3460.4089
# layer 0, epoch 211, loss_train 3446.0444
# layer 0, epoch 212, loss_train 3432.9819
# layer 0, epoch 213, loss_train 3425.7532
# layer 0, epoch 214, loss_train 3414.3191
# layer 0, epoch 215, loss_train 3414.1067
# layer 0, epoch 216, loss_train 3412.3442
# layer 0, epoch 217, loss_train 3431.7668
# layer 0, epoch 218, loss_train 3435.8101
# layer 0, epoch 219, loss_train 3447.2056
# layer 0, epoch 220, loss_train 3457.7063
# layer 0, epoch 221, loss_train 3470.4102
# layer 0, epoch 222, loss_train 3451.4175
# layer 0, epoch 223, loss_train 3416.0742
# layer 0, epoch 224, loss_train 3430.1531
# layer 0, epoch 225, loss_train 3469.0188
# layer 0, epoch 226, loss_train 3455.0181
# layer 0, epoch 227, loss_train 3455.8242
# layer 0, epoch 228, loss_train 3472.231
# layer 0, epoch 229, loss_train 3471.7722
# layer 0, epoch 230, loss_train 3460.2546
# layer 0, epoch 231, loss_train 3439.791
# layer 0, epoch 232, loss_train 3423.6626
# layer 0, epoch 233, loss_train 3399.1204
# layer 0, epoch 234, loss_train 3387.0671
# layer 0, epoch 235, loss_train 3376.8384
# layer 0, epoch 236, loss_train 3374.0464
# layer 0, epoch 237, loss_train 3369.6621
# layer 0, epoch 238, loss_train 3397.4355
# layer 0, epoch 239, loss_train 3387.4141
# layer 0, epoch 240, loss_train 3396.998
# layer 0, epoch 241, loss_train 3403.8469
# layer 0, epoch 242, loss_train 3392.4465
# layer 0, epoch 243, loss_train 3394.0925
# layer 0, epoch 244, loss_train 3387.6509
# layer 0, epoch 245, loss_train 3372.1809
# layer 0, epoch 246, loss_train 3383.8364
# layer 0, epoch 247, loss_train 3359.7085
# layer 0, epoch 248, loss_train 3380.2136
# layer 0, epoch 249, loss_train 3376.7742
# layer 1, epoch 0, loss_train 18050.9395
# layer 1, epoch 1, loss_train 17941.957
# layer 1, epoch 2, loss_train 17900.5156
# layer 1, epoch 3, loss_train 17884.6973
# layer 1, epoch 4, loss_train 17868.0469
# layer 1, epoch 5, loss_train 17858.1152
# layer 1, epoch 6, loss_train 17852.4219
# layer 1, epoch 7, loss_train 17845.207
# layer 1, epoch 8, loss_train 17837.3574
# layer 1, epoch 9, loss_train 17829.7969
# layer 1, epoch 10, loss_train 17820.9648
# layer 1, epoch 11, loss_train 17817.3711
# layer 1, epoch 12, loss_train 17812.3066
# layer 1, epoch 13, loss_train 17808.8867
# layer 1, epoch 14, loss_train 17804.9844
# layer 1, epoch 15, loss_train 17804.9727
# layer 1, epoch 16, loss_train 17804.3516
# layer 1, epoch 17, loss_train 17810.123
# layer 1, epoch 18, loss_train 17803.8535
# layer 1, epoch 19, loss_train 17796.6133
# layer 1, epoch 20, loss_train 17794.2461
# layer 1, epoch 21, loss_train 17793.5801
# layer 1, epoch 22, loss_train 17790.9629
# layer 1, epoch 23, loss_train 17789.3984
# layer 1, epoch 24, loss_train 17789.1348
# layer 2, epoch 0, loss_train 98477.4844, loss_train 100087.265625
# layer 2, epoch 1, loss_train 98444.8594, loss_train 103229.453125
# layer 2, epoch 2, loss_train 98426.5625, loss_train 105459.0859375
# layer 2, epoch 3, loss_train 98432.9531, loss_train 107091.40625
# layer 2, epoch 4, loss_train 98422.3516, loss_train 108317.7890625
# layer 2, epoch 5, loss_train 98416.1641, loss_train 109477.9140625
# layer 2, epoch 6, loss_train 98412.3594, loss_train 110511.9453125
# layer 2, epoch 7, loss_train 98404.1406, loss_train 111501.328125
# layer 2, epoch 8, loss_train 98399.7344, loss_train 112441.7265625
# layer 2, epoch 9, loss_train 98395.4219, loss_train 113297.0
# layer 2, epoch 10, loss_train 98394.3125, loss_train 114134.8828125
# layer 2, epoch 11, loss_train 98393.9375, loss_train 114910.53125
# layer 2, epoch 12, loss_train 98392.9766, loss_train 115667.4296875
# layer 2, epoch 13, loss_train 98389.8359, loss_train 116392.6640625
# layer 2, epoch 14, loss_train 98389.6797, loss_train 117092.7890625
# layer 2, epoch 15, loss_train 98389.1172, loss_train 117761.859375
# layer 2, epoch 16, loss_train 98386.6562, loss_train 118414.421875
# layer 2, epoch 17, loss_train 98382.2969, loss_train 119044.6953125
# layer 2, epoch 18, loss_train 98379.5859, loss_train 119649.5078125
# layer 2, epoch 19, loss_train 98375.2344, loss_train 120224.1953125
# layer 2, epoch 20, loss_train 98371.9297, loss_train 120822.6171875
# layer 2, epoch 21, loss_train 98369.7344, loss_train 121390.359375
# layer 2, epoch 22, loss_train 98370.5469, loss_train 121903.625
# layer 2, epoch 23, loss_train 98369.9531, loss_train 122450.046875
# layer 2, epoch 24, loss_train 98367.4531, loss_train 122842.2421875
# time used = 212.61752557754517 second

# %%
loss_log = loss_log.reshape(multi_layers,epochs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7532/3498870666.py in <module>
# ----> 1 loss_log = loss_log.reshape(multi_layers,epochs)
#
# ValueError: cannot reshape array of size 300 into shape (3,25)

# %%
number_plot = 3
plt.figure(figsize=(15,number_plot*7))
plt.subplot(411)
plt.title('Loss layer0')
plt.plot(loss_log[:250],label='train')
plt.subplot(412)
plt.title('Loss layer1')
plt.plot(loss_log[250:275],label='train')
plt.subplot(413)
plt.title('Loss layer2')
plt.plot(loss_log[275:],label='train')
plt.subplot(414)
plt.title('Loss test layer2')
plt.plot(loss_ts_log,label='test')
plt.show()

# %%
_id = 4
test_set_full = tf.expand_dims(test_set[_id],0)
fs0 = 2**(multi_layers)-1
multiplier0 = 2**(multi_layers-1)
rs0 = img_shape[0]//multiplier0
for j in range(ly+1):
    test_set_small = gauss_n_down(test_set_full,(fs0,fs0),(rs0,rs0))
    u = model_list[j](test_set_small)
    u = tf.image.resize(u,img_shape)*multiplier0
    warped_img = dense_image_warp(test_set_full[:,:,:,3:],u)
    test_set_full = tf.concat([test_set_full[:,:,:,:3],warped_img],axis=-1)
    multiplier0 = multiplier0//2
    fs0 = (fs0-1)//2
    rs0 = 2*rs0
    
diff_original = abs(test_set[_id][:,:,:3]-test_set[_id][:,:,3:])
diff_original/=np.max(diff_original)
diff_registed = abs(test_set[_id][:,:,:3]-test_set_full[0][:,:,3:])
diff_registed/=np.max(diff_registed)
plt.figure(figsize=(15,15))
plt.subplot(221)
plt.imshow(diff_original)
plt.subplot(222)
plt.imshow(diff_registed)
plt.subplot(223)
plt.imshow(test_set_full[0][:,:,:3])
plt.subplot(224)
plt.imshow(test_set_full[0][:,:,3:])
plt.show()
